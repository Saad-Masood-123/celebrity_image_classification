# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %% [markdown]
# Special thanks to Debjyoti Paul (My data scientist friend at Amazon) for help with this project

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('b.jpg')
img.shape
# Out:
# (558, 558, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (558, 558)

# %%
gray
# Out:
# array([[112, 114, 114, ..., 167, 167, 167],
#        [111, 113, 114, ..., 167, 167, 167],
#        [112, 113, 114, ..., 167, 167, 167],
#        ...,
#        [  8,   9,   9, ...,   3,   3,   3],
#        [  8,   9,   9, ...,   3,   3,   3],
#        [  8,   9,   9, ...,   3,   3,   3]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
# ✅ Load Haarcascades from OpenCV's built-in data directory
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade  = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

# ✅ Detect faces
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)
faces
# Out:
# array([[172, 142, 214, 214]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (np.int32(172), np.int32(142), np.int32(214), np.int32(214))

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (214, 214, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('b.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('b.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('b.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('b.jpg')
cropped_image_no_2_eyes
# Out:
# array([[[ 38,  28,  58],
#         [ 38,  28,  58],
#         [ 33,  25,  55],
#         ...,
#         [ 78,  69,  82],
#         [115, 109, 120],
#         [135, 131, 142]],
#
#        [[ 39,  29,  59],
#         [ 38,  28,  58],
#         [ 33,  26,  53],
#         ...,
#         [ 32,  23,  36],
#         [ 71,  65,  76],
#         [126, 122, 133]],
#
#        [[ 39,  29,  59],
#         [ 38,  28,  58],
#         [ 37,  27,  57],
#         ...,
#         [ 11,   2,  15],
#         [ 32,  26,  37],
#         [ 88,  84,  95]],
#
#        ...,
#
#        [[ 22,   8,  12],
#         [ 23,   9,  13],
#         [ 23,   9,  13],
#         ...,
#         [ 19,   6,   8],
#         [ 19,   6,   8],
#         [ 19,   6,   8]],
#
#        [[ 21,   8,  10],
#         [ 22,   9,  11],
#         [ 22,   9,  11],
#         ...,
#         [ 19,   6,   8],
#         [ 19,   6,   8],
#         [ 19,   6,   8]],
#
#        [[ 21,   8,  10],
#         [ 22,   9,  11],
#         [ 22,   9,  11],
#         ...,
#         [ 18,   5,   7],
#         [ 19,   6,   8],
#         [ 20,   7,   9]]], dtype=uint8)

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Babar',
#  './dataset/cropped',
#  './dataset/Humayun',
#  './dataset/imran']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        if entry.is_file() and entry.path.endswith("jpg"):
            print(entry.path)
            roi_color = get_cropped_image_if_2_eyes(entry.path)
            if roi_color is not None:
                cropped_folder = path_to_cr_data + celebrity_name
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_image_dirs.append(cropped_folder)
                    print("Generating cropped images in folder: ",cropped_folder)
                cropped_file_name = celebrity_name + str(count) + ".png"
                cropped_file_path = cropped_folder + "/" + cropped_file_name
                cv2.imwrite(cropped_file_path, roi_color)
                celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
                count += 1
# Out:
# ./dataset/Babar\0e0272bb82d4.jpg
# ./dataset/Babar\123445911.jpg
# ./dataset/Babar\123479120.jpg
# ./dataset/Babar\12454_8540168_updates.jpg
# ./dataset/Babar\17135400bc30b8a.jpg
# ./dataset/Babar\1755932114819_fakhar_zaman_babar_azam_virat_kohli(1).jpg
# ./dataset/Babar\18124409e40f752.jpg
# ./dataset/Babar\1_2oV-3Nb_sOAXGXZsJHSYcg.jpg
# ./dataset/Babar\291306.jpg
# Generating cropped images in folder:  ./dataset/cropped/Babar
# ./dataset/Babar\320448.1.jpg
# ./dataset/Babar\346233.6.jpg
# ./dataset/Babar\369513.3.jpg
# ./dataset/Babar\3ab8f80dee184e9231e56062c70db9cb.jpg
# ./dataset/Babar\41114_9520396_updates.jpg
# ./dataset/Babar\420124-babar-azam-wc-2023.jpg
# ./dataset/Babar\4526196-1357897152.jpg
# ./dataset/Babar\4530224-1081978418.jpg
# ./dataset/Babar\4631747-2127211271.jpg
# ./dataset/Babar\47848_7964330_updates.jpg
# ./dataset/Babar\47967_9089069_updates.jpg
# ./dataset/Babar\4bf1ec80-4843-11f0-989a-61187d103dd6.jpg
# ./dataset/Babar\59429.jpg
# ./dataset/Babar\5ce7f65146d54.jpg
# ./dataset/Babar\61e7f74aca8e8.jpg
# ./dataset/Babar\6422b7266abaab001eafc0c1.jpg
# ./dataset/Babar\9ll655pg_babar-azam_625x300_18_June_25.jpg
# ./dataset/Babar\a.jpg
# ./dataset/Babar\AFP__20240530__34UE7A9__v1__HighRes__776146379-1717617996.jpg
# ./dataset/Babar\AP23116421466279-1711875056.jpg
# ./dataset/Babar\azam.jpg
# ./dataset/Babar\b47d6989853355.5e03711042671.jpg
# ./dataset/Babar\Babar-600x789-4.jpg
# ./dataset/Babar\BABAR-ASAM.jpg
# ./dataset/Babar\Babar-Azam (1).jpg
# ./dataset/Babar\babar-azam (2).jpg
# ./dataset/Babar\Babar-Azam (3).jpg
# ./dataset/Babar\babar-azam (4).jpg
# ./dataset/Babar\Babar-Azam-1 (1).jpg
# ./dataset/Babar\babar-azam-1.jpg
# ./dataset/imran\Imran-Khan-1019-lede.jpg
# ./dataset/imran\imran-khan-11720870665-0.jpg
# ./dataset/imran\imran-khan-2-e1671426658456.jpg
# ./dataset/imran\Imran-Khan-2011.jpg
# ./dataset/imran\imran-khan-8430113_1280.jpg
# ./dataset/imran\Imran-Khan-close.jpg
# ./dataset/imran\Imran-Khan-Illustration.jpg
# ./dataset/imran\imran-khan-of-pakistan-in-action-against-india-during-a-champions-trophy-match-at-sharjah.jpg
# ./dataset/imran\imran-khan-pakistan_1baef069-364d-44a7-b0c4-cf00366eb35c-2.jpg
# ./dataset/imran\Imran-Khan-PM.jpg
# ./dataset/imran\Imran-Khan-speech-at-UnGa.jpg
# ./dataset/imran\Imran-Khan-Supreme-Court-1024x689.jpg
# ./dataset/imran\imran-khan.jpg
# ./dataset/imran\imran-khan1717524908-0-640x480.jpg
# ./dataset/imran\Imran-Pakistan-Khan.jpg
# ./dataset/imran\Imran_Khan-e1530788120173.jpg
# ./dataset/imran\Imran_Khan_in_June_2023-1200x675.jpg
# ./dataset/imran\Imran_Khan_The_Front_Row.jpg
# ./dataset/imran\l0QN9r2qvw-250.jpg
# ./dataset/imran\Latest-Imran-Khan-News.jpg
# ./dataset/imran\MV5BMjhhZWFhOTEtMWEyZi00MGU4LTliMTUtMzM0NjEwZGM2NDMwXkEyXkFqcGc@.jpg
# ./dataset/imran\pakistan-khan-lahore-september-2022-afp.jpg.jpg
# ./dataset/imran\pakistan-pm-imran-khan.jpg
# ./dataset/imran\PM-Imran-Khan-e1593006384468.jpg
# ./dataset/imran\Prime-Minister-Imran-Khan.jpg
# ./dataset/imran\Prime_Minister_Imran_Khan_Adresses_the_Forum_01.jpg
# ./dataset/imran\sc-grants-bail-to-imran-khan-in-eight-may-9-cases-1755763895-5169.jpg
# ./dataset/imran\skynews-imran-khan-addresses_4788272.jpg
# ./dataset/imran\Supreme-Court-Grants-Bail-to-Imran-Khan-in-Eight-May-9-Cases.jpg
# ./dataset/imran\thediplomat-57039993_3401350596574003_1098363991039672320_n.jpg
# ./dataset/imran\thediplomat_2024-07-15-144825.jpg
# ./dataset/imran\Untitled-design-53-3.jpg
# ./dataset/imran\_124113545_gettyimages-1001241350.jpg

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Babar': ['./dataset/cropped/Babar\\Babar1.png',
#   './dataset/cropped/Babar\\Babar10.png',
#   './dataset/cropped/Babar\\Babar11.png',
#   './dataset/cropped/Babar\\Babar12.png',
#   './dataset/cropped/Babar\\Babar14.png',
#   './dataset/cropped/Babar\\Babar15.png',
#   './dataset/cropped/Babar\\Babar16.png',
#   './dataset/cropped/Babar\\Babar17.png',
#   './dataset/cropped/Babar\\Babar18.png',
#   './dataset/cropped/Babar\\Babar19.png',
#   './dataset/cropped/Babar\\Babar2.png',
#   './dataset/cropped/Babar\\Babar20.png',
#   './dataset/cropped/Babar\\Babar3.png',
#   './dataset/cropped/Babar\\Babar4.png',
#   './dataset/cropped/Babar\\Babar5.png',
#   './dataset/cropped/Babar\\Babar6.png',
#   './dataset/cropped/Babar\\Babar7.png',
#   './dataset/cropped/Babar\\Babar8.png',
#   './dataset/cropped/Babar\\Babar9.png'],
#  'Humayun': ['./dataset/cropped/Humayun\\Humayun1.png',
#   './dataset/cropped/Humayun\\Humayun10.png',
#   './dataset/cropped/Humayun\\Humayun11.png',
#   './dataset/cropped/Humayun\\Humayun12.png',
#   './dataset/cropped/Humayun\\Humayun13.png',
#   './dataset/cropped/Humayun\\Humayun14.png',
#   './dataset/cropped/Humayun\\Humayun15.png',
#   './dataset/cropped/Humayun\\Humayun16.png',
#   './dataset/cropped/Humayun\\Humayun17.png',
#   './dataset/cropped/Humayun\\Humayun18.png',
#   './dataset/cropped/Humayun\\Humayun19.png',
#   './dataset/cropped/Humayun\\Humayun2.png',
#   './dataset/cropped/Humayun\\Humayun20.png',
#   './dataset/cropped/Humayun\\Humayun21.png',
#   './dataset/cropped/Humayun\\Humayun22.png',
#   './dataset/cropped/Humayun\\Humayun24.png',
#   './dataset/cropped/Humayun\\Humayun25.png',
#   './dataset/cropped/Humayun\\Humayun27.png',
#   './dataset/cropped/Humayun\\Humayun28.png',
#   './dataset/cropped/Humayun\\Humayun29.png',
#   './dataset/cropped/Humayun\\Humayun3.png',
#   './dataset/cropped/Humayun\\Humayun30.png',
#   './dataset/cropped/Humayun\\Humayun34.png',
#   './dataset/cropped/Humayun\\Humayun35.png',
#   './dataset/cropped/Humayun\\Humayun36.png',
#   './dataset/cropped/Humayun\\Humayun37.png',
#   './dataset/cropped/Humayun\\Humayun38.png',
#   './dataset/cropped/Humayun\\Humayun39.png',
#   './dataset/cropped/Humayun\\Humayun4.png',
#   './dataset/cropped/Humayun\\Humayun40.png',
#   './dataset/cropped/Humayun\\Humayun42.png',
#   './dataset/cropped/Humayun\\Humayun43.png',
#   './dataset/cropped/Humayun\\Humayun44.png',
#   './dataset/cropped/Humayun\\Humayun46.png',
#   './dataset/cropped/Humayun\\Humayun47.png',
#   './dataset/cropped/Humayun\\Humayun48.png',
#   './dataset/cropped/Humayun\\Humayun49.png',
#   './dataset/cropped/Humayun\\Humayun5.png',
#   './dataset/cropped/Humayun\\Humayun50.png',
#   './dataset/cropped/Humayun\\Humayun51.png',
#   './dataset/cropped/Humayun\\Humayun52.png',
#   './dataset/cropped/Humayun\\Humayun53.png',
#   './dataset/cropped/Humayun\\Humayun54.png',
#   './dataset/cropped/Humayun\\Humayun55.png',
#   './dataset/cropped/Humayun\\Humayun56.png',
#   './dataset/cropped/Humayun\\Humayun57.png',
#   './dataset/cropped/Humayun\\Humayun58.png',
#   './dataset/cropped/Humayun\\Humayun59.png',
#   './dataset/cropped/Humayun\\Humayun6.png',
#   './dataset/cropped/Humayun\\Humayun60.png',
#   './dataset/cropped/Humayun\\Humayun61.png',
#   './dataset/cropped/Humayun\\Humayun62.png',
#   './dataset/cropped/Humayun\\Humayun63.png',
#   './dataset/cropped/Humayun\\Humayun64.png',
#   './dataset/cropped/Humayun\\Humayun66.png',
#   './dataset/cropped/Humayun\\Humayun67.png',
#   './dataset/cropped/Humayun\\Humayun68.png',
#   './dataset/cropped/Humayun\\Humayun69.png',
#   './dataset/cropped/Humayun\\Humayun7.png',
#   './dataset/cropped/Humayun\\Humayun70.png',
#   './dataset/cropped/Humayun\\Humayun71.png',
#   './dataset/cropped/Humayun\\Humayun72.png',
#   './dataset/cropped/Humayun\\Humayun73.png',
#   './dataset/cropped/Humayun\\Humayun75.png',
#   './dataset/cropped/Humayun\\Humayun77.png',
#   './dataset/cropped/Humayun\\Humayun78.png',
#   './dataset/cropped/Humayun\\Humayun79.png',
#   './dataset/cropped/Humayun\\Humayun8.png',
#   './dataset/cropped/Humayun\\Humayun80.png',
#   './dataset/cropped/Humayun\\Humayun81.png',
#   './dataset/cropped/Humayun\\Humayun82.png',
#   './dataset/cropped/Humayun\\Humayun84.png',
#   './dataset/cropped/Humayun\\Humayun85.png',
#   './dataset/cropped/Humayun\\Humayun86.png',
#   './dataset/cropped/Humayun\\Humayun87.png',
#   './dataset/cropped/Humayun\\Humayun88.png',
#   './dataset/cropped/Humayun\\Humayun89.png',
#   './dataset/cropped/Humayun\\Humayun9.png',
#   './dataset/cropped/Humayun\\Humayun92.png',
#   './dataset/cropped/Humayun\\Humayun94.png',
#   './dataset/cropped/Humayun\\Humayun95.png',
#   './dataset/cropped/Humayun\\Humayun96.png',
#   './dataset/cropped/Humayun\\Humayun97.png'],
#  'imran': ['./dataset/cropped/imran\\imran1.png',
#   './dataset/cropped/imran\\imran10.png',
#   './dataset/cropped/imran\\imran11.png',
#   './dataset/cropped/imran\\imran12.png',
#   './dataset/cropped/imran\\imran13.png',
#   './dataset/cropped/imran\\imran14.png',
#   './dataset/cropped/imran\\imran15.png',
#   './dataset/cropped/imran\\imran16.png',
#   './dataset/cropped/imran\\imran17.png',
#   './dataset/cropped/imran\\imran18.png',
#   './dataset/cropped/imran\\imran19.png',
#   './dataset/cropped/imran\\imran2.png',
#   './dataset/cropped/imran\\imran20.png',
#   './dataset/cropped/imran\\imran21.png',
#   './dataset/cropped/imran\\imran22.png',
#   './dataset/cropped/imran\\imran23.png',
#   './dataset/cropped/imran\\imran24.png',
#   './dataset/cropped/imran\\imran25.png',
#   './dataset/cropped/imran\\imran27.png',
#   './dataset/cropped/imran\\imran28.png',
#   './dataset/cropped/imran\\imran29.png',
#   './dataset/cropped/imran\\imran3.png',
#   './dataset/cropped/imran\\imran30.png',
#   './dataset/cropped/imran\\imran31.png',
#   './dataset/cropped/imran\\imran32.png',
#   './dataset/cropped/imran\\imran33.png',
#   './dataset/cropped/imran\\imran34.png',
#   './dataset/cropped/imran\\imran35.png',
#   './dataset/cropped/imran\\imran36.png',
#   './dataset/cropped/imran\\imran37.png',
#   './dataset/cropped/imran\\imran38.png',
#   './dataset/cropped/imran\\imran39.png',
#   './dataset/cropped/imran\\imran4.png',
#   './dataset/cropped/imran\\imran40.png',
#   './dataset/cropped/imran\\imran42.png',
#   './dataset/cropped/imran\\imran44.png',
#   './dataset/cropped/imran\\imran45.png',
#   './dataset/cropped/imran\\imran46.png',
#   './dataset/cropped/imran\\imran47.png',
#   './dataset/cropped/imran\\imran48.png',
#   './dataset/cropped/imran\\imran49.png',
#   './dataset/cropped/imran\\imran5.png',
#   './dataset/cropped/imran\\imran50.png',
#   './dataset/cropped/imran\\imran51.png',
#   './dataset/cropped/imran\\imran6.png',
#   './dataset/cropped/imran\\imran7.png',
#   './dataset/cropped/imran\\imran8.png',
#   './dataset/cropped/imran\\imran9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Babar': 0, 'Humayun': 1, 'imran': 2}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[107],
#        [105],
#        [125],
#        ...,
#        [249],
#        [253],
#        [ 13]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (150, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.9736842105263158

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         4
#            1       0.96      1.00      0.98        26
#            2       1.00      1.00      1.00         8
#
#     accuracy                           0.97        38
#    macro avg       0.99      0.92      0.95        38
# weighted avg       0.97      0.97      0.97        38

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Saad\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.911067
# 1        random_forest    0.784980
# 2  logistic_regression    0.830435
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9736842105263158

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.9473684210526315

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8157894736842105

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 4,  0,  0],
#        [ 0, 25,  1],
#        [ 0,  0,  8]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Babar': 0, 'Humayun': 1, 'imran': 2}

# %% [markdown]
# ### Save the trained model

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))

# %%
# !python -m venv venv

# %%
# !venv\Scripts\activate
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask) (1.9.0)
# Requirement already satisfied: colorama in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saad\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\Saad\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
